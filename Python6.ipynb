# %% [markdown]
# # Самостоятельная работа (Файлы. Исключения)

# %% [markdown]
# ## Задача 1

# %% [markdown]
# Напишите функцию, которая параметром будет принимать путь к папке, а возвращать размер этой папки.

# %%
# ваш код в этой ячейке
import os

def get_folder_size(folder_path):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(folder_path):
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            if os.path.exists(file_path):
                total_size += os.path.getsize(file_path)
    return total_size

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Дан текстовый файл. В нем написан текст, разбитый на предложения. Перемешайте слова в каждом предложении текста и запишите полученный текст в новый файл.

# %%
# ваш код в этой ячейке
import random

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

sentences = text.replace('!', '.').replace('?', '.').split('.')
result_sentences = []

for sentence in sentences:
    words = sentence.strip().split()
    random.shuffle(words)
    result_sentences.append(' '.join(words))

with open('output_shuffled.txt', 'w', encoding='utf-8') as f:
    f.write('. '.join(result_sentences))

# %% [markdown]
# ## Задача 3

# %% [markdown]
# В файле расположен русский текст. Откройте этот файл, преобразуйте текст в транслит и запишите в новый файл.

# %%
# ваш код в этой ячейке
translit_dict = {
    'а': 'a', 'б': 'b', 'в': 'v', 'г': 'g', 'д': 'd', 'е': 'e', 'ё': 'yo',
    'ж': 'zh', 'з': 'z', 'и': 'i', 'й': 'y', 'к': 'k', 'л': 'l', 'м': 'm',
    'н': 'n', 'о': 'o', 'п': 'p', 'р': 'r', 'с': 's', 'т': 't', 'у': 'u',
    'ф': 'f', 'х': 'kh', 'ц': 'ts', 'ч': 'ch', 'ш': 'sh', 'щ': 'sch',
    'ъ': '', 'ы': 'y', 'ь': '', 'э': 'e', 'ю': 'yu', 'я': 'ya',
    'А': 'A', 'Б': 'B', 'В': 'V', 'Г': 'G', 'Д': 'D', 'Е': 'E', 'Ё': 'Yo',
    'Ж': 'Zh', 'З': 'Z', 'И': 'I', 'Й': 'Y', 'К': 'K', 'Л': 'L', 'М': 'M',
    'Н': 'N', 'О': 'O', 'П': 'P', 'Р': 'R', 'С': 'S', 'Т': 'T', 'У': 'U',
    'Ф': 'F', 'Х': 'Kh', 'Ц': 'Ts', 'Ч': 'Ch', 'Ш': 'Sh', 'Щ': 'Sch',
    'Ъ': '', 'Ы': 'Y', 'Ь': '', 'Э': 'E', 'Ю': 'Yu', 'Я': 'Ya'
}

with open('russian_text.txt', 'r', encoding='utf-8') as f:
    russian_text = f.read()

translit_text = ''
for char in russian_text:
    translit_text += translit_dict.get(char, char)

with open('translit_text.txt', 'w', encoding='utf-8') as f:
    f.write(translit_text)

# %% [markdown]
# ## Задача 4

# %% [markdown]
# Дан текстовый файл. Получите количество букв в нем (пробелы, знаки препинания и специальные символы не учитываются).

# %%
# ваш код в этой ячейке
import string

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

letters_count = 0
for char in text:
    if char.isalpha():
        letters_count += 1

print(f"Количество букв: {letters_count}")

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Дан текстовый файл. Получите количество букв в нем (пробелы, знаки препинания и специальные символы не учитываются).

# %%
# ваш код в этой ячейке
import re

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

letters_only = re.findall(r'[a-zA-Zа-яА-ЯёЁ]', text)
print(f"Количество букв: {len(letters_only)}")

# %% [markdown]
# ## Задача 6

# %% [markdown]
# Напишите программу, которая запрашивает у пользователя два значения. Если хотя бы одно из них не является числом, то программа будет соединять их в одну строку. В остальных случаях, если оба значения являются числами, программа будет суммировать их.
#
# Примеры выполнения программы:
# ```
# Первое значение: 10
# Второе значение: 50
# Результат: 60
# ```
#
# ```
# Первое значение: hello
# Второе значение: world
# Результат: helloworld
# ```

# %%
# ваш код в этой ячейке
value1 = input("Первое значение: ")
value2 = input("Второе значение: ")

try:
    num1 = float(value1)
    num2 = float(value2)
    result = num1 + num2
    print(f"Результат: {result}")
except ValueError:
    result = str(value1) + str(value2)
    print(f"Результат: {result}")
